# %%
import pandas as pd
import xml.etree.ElementTree as ET
import os
from modules import utility
ML_DIR = '/home/marsdenlab/projects/SV3/user_test/ml/'
MANUAL_DIR = '/home/marsdenlab/projects/SV3/user_test//manual/'

# %%
def read_xml(fn):
    f = open(fn).readlines()
    f = [s.replace('\n','') for s in f]
    f = [f[0]] + f[2:]
    f = ''.join(f)
    return ET.fromstring(f)

def parse_contour_points(element):
    c = []
    for p in element:
        a = p.attrib
        x = float(a['x'])
        y = float(a['y'])
        z = float(a['z'])
        c.append([x,y,z])
    return c

def parse_path_point(element):
    id_        = element.attrib['id']
    pos_e      = element.find('pos')
    tangent_e  = element.find('tangent')
    rotation_e = element.find('rotation')
    
    p_x = float(pos_e.attrib['x'])
    p_y = float(pos_e.attrib['y'])
    p_z = float(pos_e.attrib['z'])
    
    t_x = float(tangent_e.attrib['x'])
    t_y = float(tangent_e.attrib['y'])
    t_z = float(tangent_e.attrib['z'])
    
    r_x = float(rotation_e.attrib['x'])
    r_y = float(rotation_e.attrib['y'])
    r_z = float(rotation_e.attrib['z'])

    return [p_x,p_y,p_z,t_x,t_y,t_z,r_x,r_y,r_z], id_

def parse_contour(element):
    typ    = element.attrib['type']
    method = element.attrib['method']
    path_point = element.find('path_point')
    contour_points  = element.find('contour_points')
    initial_contour = element.find('initial_contour_points')

    p, id_    = parse_path_point(path_point)
    contour_p = parse_contour_points(contour_points)
    initial_p = parse_contour_points(initial_contour)

    print contour_p
    print initial_p
    
    if "manual" in method.lower():
        dice = 0
    elif 'splinepolygon' in typ.lower():
            pass
    else:
        dice = 1
        
    c = {"path_point":id_,"type":typ, "method":method, "dice":dice, 
         "px":p[0], "py":p[1], "pz":p[2], "tx":p[3], "ty":p[4], "tz":p[5],
        "rx":p[6], "ry":p[7], "rz":p[8]}
    return c

# %%
def get_contour_attribs(root):
    attribs = []
    for child in root:
        for c in child:
            if c.tag == 'contour':
                print c.tag
                attribs.append(c.attrib['type'] + " " + c.attrib['method'])
                
                for e in c:
                    print e.tag

# %%
ml_methods = []
for f in os.listdir(ML_DIR):
    xml = read_xml(ML_DIR+f)

print f
print xml[0][0]
a = parse_contour(xml[0][1])
print a
# Out:
# weiguang.RPA_.ctgr
# <Element 'lofting_parameters' at 0x7f2f3a886850>
# [[21.203596756590485, -6.34562185972984, 52.701693104467914], [20.963973096230966, -6.54810958560074, 53.11199461596134], [20.74836760937584, -6.74871594558831, 53.550735304689425], [20.558609316173552, -6.94553576695127, 54.013424886239534], [20.396527236772528, -7.13666387694836, 54.49557307619905], [20.263950391321213, -7.32019510283831, 54.99268959015538], [20.162707799968036, -7.49422427187987, 55.500284143695886], [20.094628482861435, -7.65684621133175, 56.01386645240796], [20.061541460149847, -7.80615574845269, 56.52894623187898], [20.065275751981705, -7.94024771050144, 57.04103319769635], [20.107660378505443, -8.05721692473671, 57.54563706544744], [20.190524359869503, -8.15515821841725, 58.03826755071963], [20.315696716222316, -8.23216641880179, 58.51443436910032], [20.48500646771232, -8.28633635314905, 58.96964723617688], [20.69934163595936, -8.31642165901494, 59.400512005454836], [20.955826248468917, -8.32381121514395, 59.808019082112196], [21.250643334217884, -8.31055271057777, 60.19425500924513], [21.579975922183156, -8.27869383435804, 60.561306329949794], [21.940007041341623, -8.23028227552645, 60.911259587322334], [22.326919720670
# UnboundLocalError: local variable 'dice' referenced before assignment

# %%
ml_set = set(ml_methods)
for s in list(ml_set):
    print s
# Out:
# SplinePolygon NN2D + Smoothed:9
# Contour NN2D + Smoothed:10  + Shifted  + Scaled
# SplinePolygon NN2D + Smoothed
# SplinePolygon NN2D + Smoothed:20
# Contour NN2D + Smoothed:10  + Scaled
# SplinePolygon NN2D + Smoothed  + Scaled + Shifted
# SplinePolygon NN2D + Smoothed:12  + Shifted  + Scaled
# Circle NN2D + Smoothed  + Shifted
# Contour NN2D + Smoothed:12  + Shifted
# SplinePolygon NN2D + Smoothed:12  + Scaled + Shifted
# SplinePolygon NN2D + Smoothed  + Shifted  + Scaled
# Contour NN2D + Smoothed:12  + Scaled + Shifted
# SplinePolygon NN2D + Smoothed:12  + Scaled
# Contour NN2D + Smoothed:12
# Contour NN2D + Smoothed  + Shifted  + Scaled
# Contour NN2D + Smoothed:10
# Contour NN2D + Smoothed  + Scaled
# Contour NN2D + Smoothed  + Scaled + Shifted
# SplinePolygon NN2D + Smoothed:9  + Scaled
# SplinePolygon NN2D + Smoothed:12
# SplinePolygon NN2D + Smoothed:10
# SplinePolygon NN2D + Smoothed  + Shifted
# SplinePolygon Manual
# Contour NN2D + Smoothed:20
# SplinePolygon NN2D + Smoothed:12  + Shifted
# Contour NN2D + Smoothed:12  + Scaled
# Contour NN2D + Smoothed  + Shifted
# Contour NN2D + Smoothed:12  + Shifted  + Scaled
# SplinePolygon NN2D + Smoothed:20  + Shifted
# SplinePolygon NN2D + Smoothed:9  + Shifted
# Contour NN2D + Smoothed
# SplinePolygon NN2D + Smoothed:10  + Shifted
# SplinePolygon NN2D + Smoothed:10  + Scaled
# SplinePolygon NN2D + Smoothed  + Scaled
# Contour NN2D + Smoothed:9

# %%
manual_methods = []
for f in os.listdir(MANUAL_DIR):
    xml = read_xml(MANUAL_DIR+f)
    l   = get_contour_attribs(xml)
    manual_methods += l

# %%
manual_set = set(manual_methods)
for s in list(manual_set):
    print s
# Out:
# SplinePolygon Threshold + Smoothed:9
# Contour Manual + Shifted  + Smoothed
# SplinePolygon Manual + Shifted
# SplinePolygon LevelSet
# Contour Legacy
# Contour Manual + Smoothed  + Shifted
# Contour Threshold + Scaled + Smoothed:9
# Contour Manual + Smoothed:9
# SplinePolygon Manual + Scaled + Smoothed
# Contour Manual + Smoothed  + Shifted  + Scaled
# SplinePolygon Manual + Smoothed  + Scaled + Shifted
# Contour LevelSet
# Contour Threshold + Smoothed:9
# SplinePolygon LevelSet + Shifted
# SplinePolygon Manual + Smoothed  + Scaled
# Contour Manual + Smoothed
# Contour LevelSet + Smoothed:9
# SplinePolygon Manual
# Contour Manual + Shifted  + Scaled + Smoothed
# SplinePolygon Manual + Shifted  + Smoothed
# Contour Manual + Smoothed  + Scaled + Shifted
# Contour Manual + Shifted  + Smoothed  + Scaled
# SplinePolygon Manual + Scaled + Shifted
# Contour Manual + Smoothed  + Scaled
# Contour Manual + Scaled + Smoothed
# SplinePolygon Manual + Shifted  + Scaled
# SplinePolygon Manual + Scaled + Shifted  + Smoothed
# Contour Threshold + Shifted  + Smoothed:9
# Contour Manual + Scaled + Shifted  + Smoothed
# SplinePolygon Manual + Shifted  + Smoothed  + Scaled
# SplinePolygon Manual + Scaled
# SplinePolygon Manual + Smoothed
