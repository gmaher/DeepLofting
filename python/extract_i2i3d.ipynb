# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Javascript
from modules import utility
import os
# Out:
# Using TensorFlow backend.

# %%
SEGS = []

# %%
class Segger:
    def __init__(self,segs):
        self.segs = segs
        
    
    def batch_seg(self,X,crop_dims):
        N=X.shape[0]
        print X.shape
        ypred=np.zeros((N,crop_dims,crop_dims,1)).astype(float)

        for i in range(0,N):
            img = X[i,:,:,0]

            ypred[i,:,:,0] = img
        if len(self.segs) == 0:
            self.segs = ypred.copy()
        else:
            self.segs = np.concatenate((self.segs,ypred.copy()))
            
        for i in range(0,N):
            ypred[i,:,:,0] = np.flipud(ypred[i,:,:,0])
            
        return utility.threshold(ypred.copy(),0.1)

seg = Segger(SEGS)

def norm(x,im):
    return x

ext = [127, 127]
DIMS = [128,128]
ISOVALUE=0.5
NUM_MODES = 5

# %%
mhas = open('images.txt').readlines()
mhas = [i.replace('\n','') for i in mhas]

truths = open('truths.txt').readlines()
truths = [i.replace('\n','') for i in truths]

paths = open('paths.txt').readlines()
paths = [i.replace('\n','') for i in paths]

groups = open('groups.txt').readlines()
groups = [i.replace('\n','') for i in groups]

ct_test = open('ct_test.txt').readlines()
ct_test = [i.replace('\n','') for i in ct_test]

mr_test = open('mr_test.txt').readlines()
mr_test = [i.replace('\n','') for i in mr_test]

# %%
volumes_dir = "/media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/"
i2i_images = os.listdir(volumes_dir)
print i2i_images
test_images = []

for v in ct_test:
    image_name = v
    print v

    ind = [i for i in range(len(mhas)) if image_name in mhas[i]][0]
    
    i2i_name = [i for i in i2i_images if v in i][0]
    
    test_images.append((volumes_dir+v+'_i2i3d.mha',truths[ind],paths[ind],groups[ind]))
    
print test_images
# Out:
# ['OSMSC0078_i2i3d.mha', 'OSMSC0006_i2i3d.mha', 'OSMSC0150_i2i3d.mha', 'OSMSC0148_i2i3d.mha', 'OSMSC0113_i2i3d.mha', 'OSMSC0179_i2i3d.mha', 'cabg11_i2i3d.mha', 'OSMSC0177_i2i3d.mha', 'OSMSC0171_i2i3d.mha', 'OSMSC0118_i2i3d.mha', 'OSMSC0144_i2i3d.mha', 'OSMSC0180_i2i3d.mha', 'OSMSC0129_i2i3d.mha', 'OSMSC0004_i2i3d.mha', 'OSMSC0101_i2i3d.mha', 'OSMSC0178_i2i3d.mha', 'OSMSC0110_i2i3d.mha', 'OSMSC0119_i2i3d.mha']
# OSMSC0004
# OSMSC0177
# cabg11
# OSMSC0179
# OSMSC0144
# OSMSC0148
# OSMSC0150
# OSMSC0119
# [('/media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0004_i2i3d.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0004/0004_0001/0004_0001-cm.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0004/0004_0001/0004_0001-cm.paths', '/home/marsdenlab/datasets/vascular_data/OSMSC0004/0004_0001/0004_0001_groups-cm'), ('/media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0177_i2i3d.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0177/0177_0000/0177_0000-cm.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0177/0177_0000/0177_0000-cm.paths', '/home/marsdenlab/datasets/vascular_data/OSMSC0177/0177_0000/0177_0000_groups-cm'), ('/media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/cabg11_i2i3d.mha', '/home/marsdenlab/datasets/vascular_data/cabg11/cabg11_all/cabg11_all.mha', '/home/marsdenlab/datasets/vascular_data/cabg11/cabg11_all/cabg11_all.paths', '/home/marsdenlab/datasets/vascular_data/cabg11/cabg11_all/cabg11_all_groups'), ('/media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0179_i2i3d.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0179/0179_0001/0179_0001-cm.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0179/0179_0001/0179_0001-cm.paths', '/home/marsdenlab/datasets/vascular_data/OSMSC0179/0179_0001/0179_0001_groups-cm'), ('/media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0144_i2i3d.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0144/0144_1001/0144_1001-cm.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0144/0144_1001/0144_1001-cm.paths', '/home/marsdenlab/datasets/vascular_data/OSMSC0144/0144_1001/0144_1001_groups-cm'), ('/media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0148_i2i3d.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0148/0148_1001/0148_1001-cm.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0148/0148_1001/0148_1001-cm.paths', '/home/marsdenlab/datasets/vascular_data/OSMSC0148/0148_1001/0148_1001_groups-cm'), ('/media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0150_i2i3d.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0150/0150_0001/0150_0001-cm.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0150/0150_0001/0150_0001-cm.paths', '/home/marsdenlab/datasets/vascular_data/OSMSC0150/0150_0001/0150_0001_groups-cm'), ('/media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0119_i2i3d.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0119/0119_0001/0119_0001-cm.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0119/0119_0001/0119_0001-cm.paths', '/home/marsdenlab/datasets/vascular_data/OSMSC0119/0119_0001/0119_0001_groups-cm')]

# %%
utility.gen_groups(test_images,seg.batch_seg,norm,
                ext,DIMS,ISOVALUE,NUM_MODES,DIMS[0],'i2i3d','./pred_groups')
# Out:
# /media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0004_i2i3d.mha
# (0.025, 0.025, 0.025)
# profunda_branch_left
# (100, 128, 128, 1)
# profunda_left
# (100, 128, 128, 1)
# knee_right
# (100, 128, 128, 1)
# profunda_branch_right
# (100, 128, 128, 1)
# anterior_tibial_right
# (100, 128, 128, 1)
# knee_left
# (100, 128, 128, 1)
# anterior_tibial_left
# (100, 128, 128, 1)
# posterior_tibial_right
# (100, 128, 128, 1)
# femoral_right
# (100, 128, 128, 1)
# posterior_tibial_left
# (100, 128, 128, 1)
# femoral_left
# (100, 128, 128, 1)
# aorta_leg_right
# (100, 128, 128, 1)
# celiac
# (50, 128, 128, 1)
# leg_left
# (100, 128, 128, 1)
# renal_right
# (50, 128, 128, 1)
# superior_mesenteric_artery
# (50, 128, 128, 1)
# internal_iliac_right
# (50, 128, 128, 1)
# renal_left
# (50, 128, 128, 1)
# profunda_right
# (100, 128, 128, 1)
# internal_iliac_left
# (50, 128, 128, 1)
# /media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0177_i2i3d.mha
# (0.025, 0.025, 0.025)
# RCCA
# (300, 128, 128, 1)
# renal_left
# (300, 128, 128, 1)
# dc_4
# (50, 128, 128, 1)
# IMA
# (300, 128, 128, 1)
# ext_iliac_left
# (300, 128, 128, 1)
# renal_right
# (300, 128, 128, 1)
# RSA
# (300, 128, 128, 1)
# aorta
# (500, 128, 128, 1)
# in_iliac_right
# (300, 128, 128, 1)
# dc_2
# (50, 128, 128, 1)
# LSA
# (300, 128, 128, 1)
# in_iliac_left
# (300, 128, 128, 1)
# LCCA
# (300, 128, 128, 1)
# celiac_splenic
# (300, 128, 128, 1)
# dc_5
# (50, 128, 128, 1)
# celiac_hepatic
# (300, 128, 128, 1)
# dc_3
# (50, 128, 128, 1)
# SMA
# (300, 128, 128, 1)
# dc_1
# (50, 128, 128, 1)
# disection
# (500, 128, 128, 1)
# /media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/cabg11_i2i3d.mha
# (0.025, 0.025, 0.025)
# lca2_3
# (300, 128, 128, 1)
# rsubcl3
# (300, 128, 128, 1)
# rsubcl3
# (300, 128, 128, 1)
# lsubcl3
# (300, 128, 128, 1)
# lca2_2
# (300, 128, 128, 1)
# lca2_2_1
# (300, 128, 128, 1)
# lsubcl2
# (300, 128, 128, 1)
# lsubcl2_1
# (300, 128, 128, 1)
# om
# (300, 128, 128, 1)
# om1
# (300, 128, 128, 1)
# l_subcl
# (300, 128, 128, 1)
# aorta
# (300, 128, 128, 1)
# rcca
# (300, 128, 128, 1)
# lcca
# (300, 128, 128, 1)
# svg1
# (300, 128, 128, 1)
# rsubcl_new
# (300, 128, 128, 1)
# lca
# (300, 128, 128, 1)
# rca
# (300, 128, 128, 1)
# rca1
# (300, 128, 128, 1)
# svg_graft2
# (300, 128, 128, 1)
# rima
# (300, 128, 128, 1)
# lca2
# (300, 128, 128, 1)
# rca2
# (300, 128, 128, 1)
# lca1
# (300, 128, 128, 1)
# lsubcl1
# (300, 128, 128, 1)
# lima
# (300, 128, 128, 1)
# rsubcl2
# (300, 128, 128, 1)
# rsubcl1
# (300, 128, 128, 1)
# rca2_extra
# (300, 128, 128, 1)
# om4
# (300, 128, 128, 1)
# om3
# (300, 128, 128, 1)
# om2
# (300, 128, 128, 1)
# svg2_extra
# (50, 128, 128, 1)
# rca1_2
# (300, 128, 128, 1)
# rca1_1
# (300, 128, 128, 1)
# lca2_1
# (300, 128, 128, 1)
# rca3
# (300, 128, 128, 1)
# /media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0179_i2i3d.mha
# (0.025, 0.025, 0.025)
# R_vtbrl_i
# (200, 128, 128, 1)
# C_ant
# (50, 128, 128, 1)
# L_incrd
# (500, 128, 128, 1)
# L_ant
# (400, 128, 128, 1)
# aneurysm_1
# (100, 128, 128, 1)
# aneurysm_2
# (50, 128, 128, 1)
# R_incrd
# (500, 128, 128, 1)
# L_vtbrl
# (500, 128, 128, 1)
# R_ant
# (400, 128, 128, 1)
# R_vtbrl_s
# (350, 128, 128, 1)
# C_left
# (50, 128, 128, 1)
# C_right
# (50, 128, 128, 1)
# /media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0144_i2i3d.mha
# (0.025, 0.025, 0.025)
# r_renal_final
# (500, 128, 128, 1)
# SMA_final
# (500, 128, 128, 1)
# l_renal_final
# (500, 128, 128, 1)
# IMA
# (150, 128, 128, 1)
# celiac_final
# (500, 128, 128, 1)
# l_illiac_final
# (1000, 128, 128, 1)
# r_in_illiac
# (500, 128, 128, 1)
# aorta_final
# (1000, 128, 128, 1)
# l_in_illiac
# (500, 128, 128, 1)
# celiac_hepatic
# (500, 128, 128, 1)
# /media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0148_i2i3d.mha
# (0.025, 0.025, 0.025)
# renal_right
# (500, 128, 128, 1)
# SMA
# (500, 128, 128, 1)
# int_iliac_left
# (500, 128, 128, 1)
# IMA
# (100, 128, 128, 1)
# int_iliac_right
# (500, 128, 128, 1)
# renal_left
# (500, 128, 128, 1)
# celiac_splenic
# (500, 128, 128, 1)
# ext_iliac_left
# (500, 128, 128, 1)
# aorta
# (1000, 128, 128, 1)
# celiac_hepatic
# (500, 128, 128, 1)
# /media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0150_i2i3d.mha
# (0.025, 0.025, 0.025)
# celiac_splenic
# (150, 128, 128, 1)
# SMA
# (250, 128, 128, 1)
# celiac_hepatic
# (100, 128, 128, 1)
# ext_iliac_left
# (200, 128, 128, 1)
# renal_left
# (120, 128, 128, 1)
# int_iliac_left
# (100, 128, 128, 1)
# aorta
# (300, 128, 128, 1)
# renal_right
# (120, 128, 128, 1)
# int_iliac_right
# (100, 128, 128, 1)
# IMA
# (120, 128, 128, 1)
# /media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0119_i2i3d.mha
# (0.025, 0.025, 0.025)
# LPA_br3
# (300, 128, 128, 1)
# LPA_br3_br1
# (300, 128, 128, 1)
# LPA_br1_br1_br4
# (300, 128, 128, 1)
# LPA_br1_br1_br4_br1
# (300, 128, 128, 1)
# LPA_br1_br1_br0
# (300, 128, 128, 1)
# LPA_br1_br1_br2
# (300, 128, 128, 1)
# LPA_br2_br1_br1
# (300, 128, 128, 1)
# LPA_br1_br1_br1
# (300, 128, 128, 1)
# LPA_br3_br2
# (300, 128, 128, 1)
# LPA_br4
# (300, 128, 128, 1)
# LPA_br6
# (300, 128, 128, 1)
# LPA_br5
# (300, 128, 128, 1)
# RPA_br11_br1
# (100, 128, 128, 1)
# RPA_br11_br2
# (100, 128, 128, 1)
# RPA_br11_br3
# (100, 128, 128, 1)
# RPA_br6_br1
# (100, 128, 128, 1)
# RPA_br10_br1
# (100, 128, 128, 1)
# RPA_br10_br2
# (100, 128, 128, 1)
# RPA_br10_br3
# (100, 128, 128, 1)
# RPA_br10_br4
# (100, 128, 128, 1)
# LPA_br13_br2_br1
# (100, 128, 128, 1)
# LPA_br13_br2
# (100, 128, 128, 1)
# LPA_br16
# (100, 128, 128, 1)
# LPA_br15
# (100, 128, 128, 1)
# RPA_br6_br2
# (100, 128, 128, 1)
# LPA_br17
# (100, 128, 128, 1)
# LPA_br4_br4_br3
# (200, 128, 128, 1)
# LPA_br4_br4_br2
# (200, 128, 128, 1)
# LPA_br4_b2_br3
# (100, 128, 128, 1)
# LPA_br4_b2_br2_br1
# (100, 128, 128, 1)
# LPA_br4_b2_br2
# (100, 128, 128, 1)
# LPA_br4_b2_br1
# (100, 128, 128, 1)
# LPA_br12_br2
# (100, 128, 128, 1)
# LPA_br12_br1
# (100, 128, 128, 1)
# LPA_br4_b2_br4
# (100, 128, 128, 1)
# LPA_br4_b2_br3_b1
# (100, 128, 128, 1)
# LPA_br10_br1
# (100, 128, 128, 1)
# LPA_br12_br3
# (100, 128, 128, 1)
# RPA_br2_br3
# (100, 128, 128, 1)
# RPA_br2_br2
# (100, 128, 128, 1)
# RPA_br1_br2_b2
# (100, 128, 128, 1)
# RPA_br1_br2_b1
# (100, 128, 128, 1)
# RPA_br1_br2
# (100, 128, 128, 1)
# RPA_br1_br1_br4
# (100, 128, 128, 1)
# RPA_br10
# (100, 128, 128, 1)
# RPA_br9
# (100, 128, 128, 1)
# RPA_br12
# (100, 128, 128, 1)
# RPA_br11
# (300, 128, 128, 1)
# LPA_br10_br2
# (100, 128, 128, 1)
# LPA_br10_br3
# (100, 128, 128, 1)
# LPA_br10_br4
# (100, 128, 128, 1)
# LPA_br10_br5
# (100, 128, 128, 1)
# LPA_br10_br6
# (100, 128, 128, 1)
# RPA_br1
# (300, 128, 128, 1)
# LPA_br10_br8
# (100, 128, 128, 1)
# LPA_br10_br8_b1
# (100, 128, 128, 1)
# LPA_br10_br9
# (100, 128, 128, 1)
# LPA_br13_br1
# (100, 128, 128, 1)
# RPA_br4
# (300, 128, 128, 1)
# LPA_br9_5_br1
# (100, 128, 128, 1)
# RPA_br1_br1_br3_b2
# (100, 128, 128, 1)
# RPA_br1_br1_br3_b3
# (100, 128, 128, 1)
# RPA_br1_br1
# (100, 128, 128, 1)
# RPA_br1_br1_br1
# (100, 128, 128, 1)
# RPA_br1_br1_br2
# (100, 128, 128, 1)
# RPA_br1_br1_br2_b1
# (100, 128, 128, 1)
# RPA_br1_br1_br2_b2
# (100, 128, 128, 1)
# RPA_br1_br1_br3
# (100, 128, 128, 1)
# RPA_br1_br1_br3_br1
# (100, 128, 128, 1)
# LPA_br8_b3
# (100, 128, 128, 1)
# LPA_br8_b2
# (100, 128, 128, 1)
# LPA_br8_b5
# (100, 128, 128, 1)
# LPA_br8_b4
# (100, 128, 128, 1)
# LPA_br7_b1_b1
# (100, 128, 128, 1)
# LPA_br7_b1
# (100, 128, 128, 1)
# LPA_br8_b1
# (100, 128, 128, 1)
# LPA_br6_b1
# (100, 128, 128, 1)
# RPA
# (500, 128, 128, 1)
# LPA_br9_b1
# (300, 128, 128, 1)
# LPA_br6_b2
# (100, 128, 128, 1)
# RPA_br9_br3
# (100, 128, 128, 1)
# RPA_br9_br2
# (100, 128, 128, 1)
# RPA_br7_br7
# (100, 128, 128, 1)
# RPA_br7_br6
# (100, 128, 128, 1)
# RPA_br9_br1
# (100, 128, 128, 1)
# RPA_br7_br8
# (100, 128, 128, 1)
# RPA_br7_br3
# (100, 128, 128, 1)
# RPA_br7_br2
# (100, 128, 128, 1)
# RPA_br7_br5
# (100, 128, 128, 1)
# RPA_br7_br4
# (100, 128, 128, 1)
# LPA_br4_br4_br1
# (200, 128, 128, 1)
# LPA_br4_br5
# (100, 128, 128, 1)
# LPA_br9_b3
# (100, 128, 128, 1)
# LPA_br9_b3_b1
# (100, 128, 128, 1)
# LPA_br9_b1_b2
# (100, 128, 128, 1)
# LPA_br9_b2
# (100, 128, 128, 1)
# LPA_br9_5_br2
# (100, 128, 128, 1)
# LPA_br4_br4
# (200, 128, 128, 1)
# LPA_br9_b1_b3
# (100, 128, 128, 1)
# RPA_br7
# (100, 128, 128, 1)
# RPA_br8
# (100, 128, 128, 1)
# RPA_br2_br1
# (100, 128, 128, 1)
# RPA_br1_br2_b4
# (100, 128, 128, 1)
# RPA_br1_br2_b3
# (100, 128, 128, 1)
# LPA_br11
# (300, 128, 128, 1)
# LPA_br10
# (300, 128, 128, 1)
# LPA_br9
# (300, 128, 128, 1)
# LPA_br8
# (300, 128, 128, 1)
# LPA_br7
# (300, 128, 128, 1)
# RPA_br1_br2_b2_b1
# (100, 128, 128, 1)
# RPA_br6
# (300, 128, 128, 1)
# LPA_br4_b2
# (300, 128, 128, 1)
# LPA_br4_br1_br1
# (300, 128, 128, 1)
# LPA_br4_br1
# (300, 128, 128, 1)
# LPA_br18
# (100, 128, 128, 1)
# RPA_br6_br3
# (100, 128, 128, 1)
# LPA_br10_br7
# (100, 128, 128, 1)
# RPA_br5
# (300, 128, 128, 1)
# LPA_br5_br2
# (100, 128, 128, 1)
# LPA_br5_br2_b1
# (100, 128, 128, 1)
# LPA_br4_br3
# (300, 128, 128, 1)
# LPA_br4_br3_br1
# (100, 128, 128, 1)
# LPA_br5_br1
# (300, 128, 128, 1)
# LPA_br5_br1_br1
# (100, 128, 128, 1)
# LPA_br9.5
# (300, 128, 128, 1)
# LPA_br12
# (300, 128, 128, 1)
# LPA_br13
# (300, 128, 128, 1)
# LPA_br14
# (300, 128, 128, 1)
# RPA_br4_br2
# (100, 128, 128, 1)
# RPA_br4_br2_b1
# (100, 128, 128, 1)
# RPA_br2_br4
# (100, 128, 128, 1)
# RPA_br4_br1
# (100, 128, 128, 1)
# RPA_br5_br1
# (100, 128, 128, 1)
# RPA_br5_br1_b1
# (100, 128, 128, 1)
# RPA_br4_br3
# (100, 128, 128, 1)
# RPA_br4_br4
# (100, 128, 128, 1)
# RPA_br2_br5
# (100, 128, 128, 1)
# RPA_br7_br1
# (100, 128, 128, 1)
# LPA_br1
# (300, 128, 128, 1)
# LPA
# (500, 128, 128, 1)
# LPA_br2
# (300, 128, 128, 1)
# LPA_br1_br1
# (300, 128, 128, 1)
# LPA_br1_br2
# (300, 128, 128, 1)
# LPA_br2_br1
# (300, 128, 128, 1)
# LPA_br1_br3_br1
# (300, 128, 128, 1)
# LPA_br1_br3
# (300, 128, 128, 1)
# LPA_br1_br4_br1
# (300, 128, 128, 1)
# RPA_br2
# (500, 128, 128, 1)
# RPA_br8_br2
# (100, 128, 128, 1)
# RPA_br8_br1
# (100, 128, 128, 1)
# RPA_br10_br5
# (100, 128, 128, 1)
# RPA_br12_br4
# (100, 128, 128, 1)
# RPA_br12_br3
# (100, 128, 128, 1)
# RPA_br12_br2
# (100, 128, 128, 1)
# RPA_br12_br1
# (100, 128, 128, 1)
# RPA_br6_br4
# (100, 128, 128, 1)

# %%
print seg.segs.shape
np.save('i2i3d_segs_ct.npy',seg.segs)
# Out:
# (40450, 128, 128, 1)

# %%
SEGS = np.load('i2i3d_segs_ct.npy')
N = len(SEGS)
conts = []
for i in range(N):
    if i %1000==0:
        print i
    seg_ = SEGS[i,:,:,0]
    seg_ = utility.threshold(seg_,0.05)
    cont = utility.marchingSquares(seg_.astype(np.float32),iso=0.1,mode='center')
    conts.append(cont)
    

np.save('i2i3d_conts_ct.npy',conts)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000

# %%
plt.imshow(SEGS[0,:,:,0])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-c38deafb9335> in <module>()
# ----> 1 plt.imshow(SEGS[0,:,:,0])
#       2 plt.show()
#
# TypeError: list indices must be integers, not tuple

# %%
volumes_dir = "/media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/"
i2i_images = os.listdir(volumes_dir)
print i2i_images
test_images = []

for v in mr_test:
    image_name = v
    print v

    ind = [i for i in range(len(mhas)) if image_name in mhas[i]][0]
    
    i2i_name = [i for i in i2i_images if v in i][0]
    
    test_images.append((volumes_dir+v+'_i2i3d.mha',truths[ind],paths[ind],groups[ind]))
    
print test_images
# Out:
# ['OSMSC0078_i2i3d.mha', 'OSMSC0006_i2i3d.mha', 'OSMSC0150_i2i3d.mha', 'OSMSC0148_i2i3d.mha', 'OSMSC0113_i2i3d.mha', 'OSMSC0179_i2i3d.mha', 'cabg11_i2i3d.mha', 'OSMSC0177_i2i3d.mha', 'OSMSC0171_i2i3d.mha', 'OSMSC0118_i2i3d.mha', 'OSMSC0144_i2i3d.mha', 'OSMSC0180_i2i3d.mha', 'OSMSC0129_i2i3d.mha', 'OSMSC0004_i2i3d.mha', 'OSMSC0101_i2i3d.mha', 'OSMSC0178_i2i3d.mha', 'OSMSC0110_i2i3d.mha', 'OSMSC0119_i2i3d.mha']
# OSMSC0006
# OSMSC0101
# OSMSC0171
# OSMSC0178
# OSMSC0110
# [('/media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0006_i2i3d.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0006/0006_0001/0006_0001-cm.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0006/0006_0001/0006_0001-cm.paths', '/home/marsdenlab/datasets/vascular_data/OSMSC0006/0006_0001/0006_0001_groups-cm'), ('/media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0101_i2i3d.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0101/0101_0001/0101_0001-cm.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0101/0101_0001/0101_0001-cm.paths', '/home/marsdenlab/datasets/vascular_data/OSMSC0101/0101_0001/0101_0001_groups-cm'), ('/media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0171_i2i3d.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0171/0171_0001/0171_0001-cm.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0171/0171_0001/0171_0001-cm.paths', '/home/marsdenlab/datasets/vascular_data/OSMSC0171/0171_0001/0171_0001_groups-cm'), ('/media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0178_i2i3d.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0178/0178_0001/0178_0001-cm.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0178/0178_0001/0178_0001-cm.paths', '/home/marsdenlab/datasets/vascular_data/OSMSC0178/0178_0001/0178_0001_groups-cm'), ('/media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0110_i2i3d.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0110/0110_0001/0110_0001-cm.mha', '/home/marsdenlab/datasets/vascular_data/OSMSC0110/0110_0001/0110_0001-cm.paths', '/home/marsdenlab/datasets/vascular_data/OSMSC0110/0110_0001/0110_0001_groups-cm')]

# %%
utility.gen_groups(test_images,seg.batch_seg,norm,
                ext,DIMS,ISOVALUE,NUM_MODES,DIMS[0],'i2i3d','./pred_groups')
# Out:
# /media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0006_i2i3d.mha
# (0.025, 0.025, 0.025)
# right_iliac
# (100, 128, 128, 1)
# celiac_branch
# (25, 128, 128, 1)
# left_internal_iliac
# (100, 128, 128, 1)
# celiac_trunk
# (75, 128, 128, 1)
# renal_right
# (50, 128, 128, 1)
# right_internal_iliac
# (100, 128, 128, 1)
# renal_left
# (50, 128, 128, 1)
# aorta
# (300, 128, 128, 1)
# superior_mesentaric
# (75, 128, 128, 1)
# /media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0101_i2i3d.mha
# (0.025, 0.025, 0.025)
# rt_carotid_final
# (250, 128, 128, 1)
# btrunk_final
# (300, 128, 128, 1)
# aorta_final
# (500, 128, 128, 1)
# subclavian_final
# (300, 128, 128, 1)
# carotid_final
# (300, 128, 128, 1)
# /media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0171_i2i3d.mha
# (0.025, 0.025, 0.025)
# R_antrb_b1
# (150, 128, 128, 1)
# R_antrb
# (250, 128, 128, 1)
# L_incrd_b14
# (250, 128, 128, 1)
# L_incrd_b15
# (250, 128, 128, 1)
# L_incrd_b12
# (250, 128, 128, 1)
# L_incrd_b13
# (250, 128, 128, 1)
# L_incrd_b10
# (250, 128, 128, 1)
# L_incrd_b11
# (250, 128, 128, 1)
# R_antrb_b2
# (150, 128, 128, 1)
# R_incrd_b11
# (250, 128, 128, 1)
# R_incrd_b10
# (250, 128, 128, 1)
# R_incrd_b12
# (250, 128, 128, 1)
# L_antrb_b2
# (150, 128, 128, 1)
# L_antrb
# (250, 128, 128, 1)
# L_antrb_b1
# (250, 128, 128, 1)
# R_pcoma
# (100, 128, 128, 1)
# R_vtbrl
# (350, 128, 128, 1)
# L_vtbrl_ppst
# (250, 128, 128, 1)
# L_vtbrl_pre
# (200, 128, 128, 1)
# L_incrd_b1
# (250, 128, 128, 1)
# L_incrd
# (350, 128, 128, 1)
# L_incrd_b3
# (250, 128, 128, 1)
# L_incrd_b2
# (250, 128, 128, 1)
# L_incrd_b5
# (250, 128, 128, 1)
# L_incrd_b4
# (250, 128, 128, 1)
# L_incrd_b7
# (250, 128, 128, 1)
# L_incrd_b6
# (250, 128, 128, 1)
# L_incrd_b9
# (250, 128, 128, 1)
# R_vtbrl_b1
# (250, 128, 128, 1)
# R_vtbrl_b2
# (250, 128, 128, 1)
# R_vtbrl_b3
# (250, 128, 128, 1)
# R_vtbrl_b4
# (250, 128, 128, 1)
# R_vtbrl_b5
# (250, 128, 128, 1)
# R_vtbrl_b6
# (250, 128, 128, 1)
# R_vtbrl_b7
# (250, 128, 128, 1)
# R_incrd_b8
# (250, 128, 128, 1)
# R_incrd_b9
# (250, 128, 128, 1)
# R_incrd_b2
# (250, 128, 128, 1)
# R_incrd_b3
# (250, 128, 128, 1)
# R_incrd
# (350, 128, 128, 1)
# R_incrd_b1
# (250, 128, 128, 1)
# R_incrd_b6
# (250, 128, 128, 1)
# R_incrd_b7
# (250, 128, 128, 1)
# R_incrd_b4
# (250, 128, 128, 1)
# R_incrd_b5
# (250, 128, 128, 1)
# L_vtbrl_b4
# (250, 128, 128, 1)
# L_vtbrl_b5
# (250, 128, 128, 1)
# L_incrd_b8
# (250, 128, 128, 1)
# L_vtbrl_b1
# (250, 128, 128, 1)
# L_vtbrl_b2
# (250, 128, 128, 1)
# L_vtbrl_b3
# (250, 128, 128, 1)
# L_pcoma
# (100, 128, 128, 1)
# /media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0178_i2i3d.mha
# (0.025, 0.025, 0.025)
# L_incrd
# (500, 128, 128, 1)
# C_right
# (100, 128, 128, 1)
# L_ant
# (400, 128, 128, 1)
# R_vtrbl
# (500, 128, 128, 1)
# C_ant
# (100, 128, 128, 1)
# L_vtrbl_s
# (300, 128, 128, 1)
# R_ant
# (400, 128, 128, 1)
# L_vtrbl_i
# (200, 128, 128, 1)
# R_incrd
# (500, 128, 128, 1)
# C_left
# (100, 128, 128, 1)
# aneurysm_2
# (50, 128, 128, 1)
# aneurysm_1
# (50, 128, 128, 1)
# /media/marsdenlab/Data2/datasets/DeepLofting/i2i3d/OSMSC0110_i2i3d.mha
# (0.025, 0.025, 0.025)
# left_rental
# (300, 128, 128, 1)
# right_iliac_branch2
# (100, 128, 128, 1)
# right_inf_renal
# (300, 128, 128, 1)
# left_iliac_branch2
# (100, 128, 128, 1)
# right_rental
# (300, 128, 128, 1)
# superior_mesenteric_branch1
# (100, 128, 128, 1)
# celiac_trunk
# (300, 128, 128, 1)
# splenic
# (300, 128, 128, 1)
# celiac_trunk_branch1
# (300, 128, 128, 1)
# splenic_branch1
# (100, 128, 128, 1)
# superior_mesenteric
# (300, 128, 128, 1)
# right_iliac_internal
# (200, 128, 128, 1)
# left_iliac_internal
# (200, 128, 128, 1)
# aorta
# (300, 128, 128, 1)
# right_iliac
# (200, 128, 128, 1)
# inferior_mesenteric_artery
# (300, 128, 128, 1)
# left_sup_renal
# (300, 128, 128, 1)
# right_iliac_branch1
# (100, 128, 128, 1)
# left_iliac_branch1
# (100, 128, 128, 1)
